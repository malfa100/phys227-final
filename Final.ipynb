# %%
from IPython.display import Image

import final as p1

# %% [markdown]
# # PHYS227 Final
# ### Andrew Malfavon

# %% [markdown]
# Explore nonlinearity in the coupled first-order ODEs:
# $$\dot{x}=-y-z, \qquad \dot{y}=x+ay, \qquad \dot{z}=b+z(x-c)$$
# where $x(t), \ y(t), \ z(t)$ are real-valued functions of time and $a=b=0.2$ and $c$ is a parameter that will be tuned.

# %% [markdown]
# ## Part 1
# Implement a 4th-order Runge-Kutta for the ODEs and graph in different methods to visualize the solutions:
# $$c = 2$$ and $$x(0)=y(0)=z(0)=0$$

# %% [markdown]
# Plot of $x \ vs.\ t$:

# %%
a = p1.Rossler(2)
a.run()
a.plotx()

# %% [markdown]
# Plot of $y \ vs.\ t$:

# %%
a.ploty()

# %% [markdown]
# Plot of $z \ vs.\ t$:

# %%
a.plotz()

# %% [markdown]
# Plot of $y \ vs.\ x$:

# %%
a.plotxy()

# %% [markdown]
# Plot of $z \ vs.\ y$:

# %%
a.plotyz()

# %% [markdown]
# Plot of $z \ vs.\ x$:

# %%
a.plotxz()

# %% [markdown]
# $3$-D $x-y-z$ plot:

# %%
a.plotxyz()

# %% [markdown]
# ## Part 2
# To depict the onset of chaos, $x(t), \ y(x),$ and $z(x, y)$ are graphed for $c$ values $2, 3, 4, 4.15, 4.2$ and $5.7$:

# %%
c_2 = p1.Rossler(2)
c_3 = p1.Rossler(3)
c_4 = p1.Rossler(4)
c_4point15 = p1.Rossler(4.15)
c_4point2 = p1.Rossler(4.2)
c_5point7 = p1.Rossler(5.7)

# %% [markdown]
# The $x(t)$ plots are periodic for smaller $c$ values, but become increasingly chaotic with increasing $c$:

# %%
c_2.run()
c_2.plotx()

# %%
c_3.run()
c_3.plotx()

# %%
c_4.run()
c_4.plotx()

# %%
c_4point15.run()
c_4point15.plotx()

# %%
c_4point2.run()
c_4point2.plotx()

# %%
c_5point7.run()
c_5point7.plotx()

# %% [markdown]
# The $y(x)$ plots display closed paths, beginning with one loop and doubling with increasing $c$ until it too reaches chaotic behavior.

# %%
c_2.run()
c_2.plotxy()

# %%
c_3.run()
c_3.plotxy()

# %%
c_4.run()
c_4.plotxy()

# %%
c_4point15.run()
c_4point15.plotxy()

# %%
c_4point2.run()
c_4point2.plotxy()

# %%
c_5point7.run()
c_5point7.plotxy()

# %% [markdown]
# The $z(x,y)$ solutions create a $3$-D plot which is similar to the $y\ vs.\ x$ plots except the loops curve up toward positive $z$ as $y$ increases.

# %%
c_2.run()
c_2.plotxyz()

# %%
c_3.run()
c_3.plotxyz()

# %%
c_4.run()
c_4.plotxyz()

# %%
c_4point15.run()
c_4point15.plotxyz()

# %%
c_4point2.run()
c_4point2.plotxyz()

# %%
c_5point7.run()
c_5point7.plotxyz()

# %% [markdown]
# ## Part 3
# For each value of $c$ in the range $[2,6]$ (with a small mesh spacing of $0.001$, a local maxima of a particular solution $x(t), \ y(t)$, and $z(t)$ for $t>T0$, the solutions to the ODEs are plotted on a Maxima vs. $c$ scatter plot. The three graphs are for $x(t), y(t)$, and $z(t)$ respectively. $dt = 0.001$ from the previous solutions to the Runge-Kutta implementation is changed to $dt=0.1$ to reduce the number of iterations. The run-time is still fairly long, about $8$ minutes, so with the original $dt=0.001$, the run-time would be more than $13$ hours long.

# %%
p1.plotmaxima(0)

# %%
p1.plotmaxima(1)

# %%
p1.plotmaxima(2)

# %% [markdown]
# The local maximum values plotted vs. the $c$ values used to get the maximum values creates a bifurcation diagram similar to that created in the midterm. The $x, y,$, and $z$ bifurcations have similar patterns but differ in the asymptotic local maxima. The midterm utilized the logistic equation, while this example uses a local maxima which occurs once per cycle. The period doubling pattern is displayed, turning to chaotic behavior with areas of non-chaotic behavior appearing sporadically. From the previous $2$ and $3$ dimensional graphs, we have seen that the $x, y$, and $z$ functions solved differe in results, so the different asymptotic local maxima shown here makes sense.

# %% [markdown]
# The following image is the Mathematica numerical solution for $x(500), y(500)$, and $z(500)$, used to test the run function accuracy:

# %%
Image(filename='mathematica.png')
